# %%
# Import dependencies 
import random
import pandas as pd
import numpy as np
from citipy import citipy
import requests
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
longs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_longs = zip(lats, longs)
lat_longs

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in lat_longs:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 740

# %%
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=37ade6e8e8dc1bfc8302dcf7defad13a

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete")
# Out:
# Processing Record 1 of Set 1 | arvika
# Processing Record 2 of Set 1 | khatanga
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | nanortalik
# Processing Record 5 of Set 1 | yajalon
# Processing Record 6 of Set 1 | lodja
# Processing Record 7 of Set 1 | poum
# Processing Record 8 of Set 1 | ahipara
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | zhaocheng
# City not found. Skipping...
# Processing Record 11 of Set 1 | beloha
# Processing Record 12 of Set 1 | chulym
# Processing Record 13 of Set 1 | cherskiy
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | hobart
# Processing Record 16 of Set 1 | new norfolk
# Processing Record 17 of Set 1 | lardos
# Processing Record 18 of Set 1 | san jose
# Processing Record 19 of Set 1 | cuiluan
# Processing Record 20 of Set 1 | luoyang
# Processing Record 21 of Set 1 | black river
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | ternitz
# Processing Record 24 of Set 1 | kidal
# Processing Record 25 of Set 1 | pionerskiy
# Processing Record 26 of Set 1 | torbay
# Processing Record 27 of Set 1 | tadine
# Processing Record 28 of Set 1 | barrow
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | codrington
# Processing Record 31 of Set 1 | vung tau
# Processing Record 32 of Set 1 | husavik
# Processing Record 33 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 1 | derzhavinsk
# Processing Record 35 of Set 1 | sioux lookout
# Processing Record 36 of Set 1 | mount gambier
# Processing Record 37 of Set 1 | saint george
# Processing Record 38 of Set 1 | dikson
# Processing Record 39 of Set 1 | sisimiut
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | kodiak
# Processing Record 42 of Set 1 | namibe
# Processing Record 43 of Set 1 | burgeo
# Processing Record 44 of Set 1 | bredasdorp
# Processing Record 45 of Set 1 | yulara
# Processing Record 46 of Set 1 | carnarvon
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | portland
# Processing Record 49 of Set 1 | luderitz
# Processing Record 50 of Set 1 | dunhua
# Processing Record 1 of Set 2 | sao filipe
# Processing Record 2 of Set 2 | hithadhoo
# Processing Record 3 of Set 2 | bima
# Processing Record 4 of Set 2 | tocopilla
# Processing Record 5 of Set 2 | bamiantong
# Processing Record 6 of Set 2 | srednekolymsk
# Processing Record 7 of Set 2 | cabo san lucas
# Processing Record 8 of Set 2 | saldanha
# Processing Record 9 of Set 2 | isangel
# Processing Record 10 of Set 2 | maridi
# Processing Record 11 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 2 | ejea de los caballeros
# Processing Record 13 of Set 2 | inuvik
# Processing Record 14 of Set 2 | naze
# Processing Record 15 of Set 2 | caravelas
# Processing Record 16 of Set 2 | punta arenas
# Processing Record 17 of Set 2 | hamilton
# Processing Record 18 of Set 2 | biloxi
# Processing Record 19 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 2 | san patricio
# Processing Record 21 of Set 2 | nikolskoye
# Processing Record 22 of Set 2 | komsomolskiy
# Processing Record 23 of Set 2 | san francisco
# Processing Record 24 of Set 2 | roald
# Processing Record 25 of Set 2 | hermanus
# Processing Record 26 of Set 2 | sao joao da barra
# Processing Record 27 of Set 2 | valley city
# Processing Record 28 of Set 2 | kruisfontein
# Processing Record 29 of Set 2 | cavarzere
# Processing Record 30 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 2 | ushuaia
# Processing Record 32 of Set 2 | iqaluit
# Processing Record 33 of Set 2 | sakakah
# Processing Record 34 of Set 2 | jamestown
# Processing Record 35 of Set 2 | bella vista
# Processing Record 36 of Set 2 | paamiut
# Processing Record 37 of Set 2 | upernavik
# Processing Record 38 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 2 | nouadhibou
# Processing Record 41 of Set 2 | ewa beach
# Processing Record 42 of Set 2 | constitucion
# Processing Record 43 of Set 2 | vaini
# Processing Record 44 of Set 2 | avarua
# Processing Record 45 of Set 2 | chala
# Processing Record 46 of Set 2 | sur
# Processing Record 47 of Set 2 | kaeo
# Processing Record 48 of Set 2 | kapaa
# Processing Record 49 of Set 2 | mar del plata
# Processing Record 50 of Set 2 | butaritari
# Processing Record 1 of Set 3 | sinkat
# City not found. Skipping...
# Processing Record 2 of Set 3 | saint-augustin
# Processing Record 3 of Set 3 | kadoshkino
# Processing Record 4 of Set 3 | barceloneta
# Processing Record 5 of Set 3 | okhotsk
# Processing Record 6 of Set 3 | alghero
# Processing Record 7 of Set 3 | the valley
# Processing Record 8 of Set 3 | haines junction
# Processing Record 9 of Set 3 | ribeira grande
# Processing Record 10 of Set 3 | maragogi
# Processing Record 11 of Set 3 | tolaga bay
# Processing Record 12 of Set 3 | praya
# Processing Record 13 of Set 3 | severo-kurilsk
# Processing Record 14 of Set 3 | aksarayskiy
# Processing Record 15 of Set 3 | hofn
# Processing Record 16 of Set 3 | udachnyy
# Processing Record 17 of Set 3 | georgetown
# Processing Record 18 of Set 3 | mont-de-marsan
# Processing Record 19 of Set 3 | shevchenkove
# Processing Record 20 of Set 3 | lasa
# Processing Record 21 of Set 3 | narsaq
# Processing Record 22 of Set 3 | norman wells
# Processing Record 23 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 24 of Set 3 | biltine
# Processing Record 25 of Set 3 | provideniya
# Processing Record 26 of Set 3 | hasaki
# Processing Record 27 of Set 3 | inderborskiy
# City not found. Skipping...
# Processing Record 28 of Set 3 | puerto ayora
# Processing Record 29 of Set 3 | muana
# Processing Record 30 of Set 3 | touros
# Processing Record 31 of Set 3 | slave lake
# Processing Record 32 of Set 3 | kattivakkam
# Processing Record 33 of Set 3 | mizdah
# Processing Record 34 of Set 3 | mustafabad
# Processing Record 35 of Set 3 | saskylakh
# Processing Record 36 of Set 3 | guadalupe y calvo
# Processing Record 37 of Set 3 | labuhan
# Processing Record 38 of Set 3 | port elizabeth
# Processing Record 39 of Set 3 | victoria
# Processing Record 40 of Set 3 | qaanaaq
# Processing Record 41 of Set 3 | gallup
# Processing Record 42 of Set 3 | hilo
# Processing Record 43 of Set 3 | san policarpo
# Processing Record 44 of Set 3 | ottumwa
# Processing Record 45 of Set 3 | doha
# Processing Record 46 of Set 3 | saint-philippe
# Processing Record 47 of Set 3 | port alfred
# Processing Record 48 of Set 3 | beringovskiy
# Processing Record 49 of Set 3 | seoul
# Processing Record 50 of Set 3 | isiro
# Processing Record 1 of Set 4 | ancud
# Processing Record 2 of Set 4 | pozo colorado
# Processing Record 3 of Set 4 | saryshagan
# City not found. Skipping...
# Processing Record 4 of Set 4 | dingle
# Processing Record 5 of Set 4 | byron bay
# Processing Record 6 of Set 4 | kasongo
# Processing Record 7 of Set 4 | nalut
# Processing Record 8 of Set 4 | ferme-neuve
# Processing Record 9 of Set 4 | karamea
# City not found. Skipping...
# Processing Record 10 of Set 4 | lithakia
# Processing Record 11 of Set 4 | thompson
# Processing Record 12 of Set 4 | chara
# Processing Record 13 of Set 4 | port lincoln
# Processing Record 14 of Set 4 | tiksi
# Processing Record 15 of Set 4 | talnakh
# Processing Record 16 of Set 4 | chokurdakh
# Processing Record 17 of Set 4 | vila velha
# Processing Record 18 of Set 4 | ponta do sol
# Processing Record 19 of Set 4 | east london
# Processing Record 20 of Set 4 | nueva gerona
# Processing Record 21 of Set 4 | manchar
# Processing Record 22 of Set 4 | monroe
# Processing Record 23 of Set 4 | margate
# Processing Record 24 of Set 4 | padang
# Processing Record 25 of Set 4 | lavrentiya
# Processing Record 26 of Set 4 | esperance
# Processing Record 27 of Set 4 | sarkand
# Processing Record 28 of Set 4 | ballina
# Processing Record 29 of Set 4 | petawawa
# Processing Record 30 of Set 4 | laguna
# Processing Record 31 of Set 4 | gizo
# Processing Record 32 of Set 4 | dukat
# Processing Record 33 of Set 4 | richards bay
# Processing Record 34 of Set 4 | hellvik
# Processing Record 35 of Set 4 | clyde river
# Processing Record 36 of Set 4 | pevek
# Processing Record 37 of Set 4 | bonavista
# Processing Record 38 of Set 4 | tasiilaq
# Processing Record 39 of Set 4 | geraldton
# Processing Record 40 of Set 4 | castro
# Processing Record 41 of Set 4 | sao jose de ribamar
# Processing Record 42 of Set 4 | shihezi
# Processing Record 43 of Set 4 | mumford
# Processing Record 44 of Set 4 | kaili
# Processing Record 45 of Set 4 | sataua
# City not found. Skipping...
# Processing Record 46 of Set 4 | pecos
# Processing Record 47 of Set 4 | evensk
# Processing Record 48 of Set 4 | katsuura
# Processing Record 49 of Set 4 | areosa
# Processing Record 50 of Set 4 | saint-pierre
# Processing Record 1 of Set 5 | korla
# Processing Record 2 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 5 | nemuro
# Processing Record 4 of Set 5 | roma
# Processing Record 5 of Set 5 | khandyga
# Processing Record 6 of Set 5 | mtsensk
# Processing Record 7 of Set 5 | xai-xai
# Processing Record 8 of Set 5 | jatai
# Processing Record 9 of Set 5 | kahului
# Processing Record 10 of Set 5 | tharad
# Processing Record 11 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 5 | vallenar
# Processing Record 13 of Set 5 | nuevo progreso
# Processing Record 14 of Set 5 | temir
# Processing Record 15 of Set 5 | tessalit
# Processing Record 16 of Set 5 | galiwinku
# City not found. Skipping...
# Processing Record 17 of Set 5 | staunton
# Processing Record 18 of Set 5 | la ronge
# Processing Record 19 of Set 5 | hinton
# Processing Record 20 of Set 5 | praia da vitoria
# Processing Record 21 of Set 5 | salalah
# Processing Record 22 of Set 5 | alta floresta
# Processing Record 23 of Set 5 | bouza
# Processing Record 24 of Set 5 | grand gaube
# Processing Record 25 of Set 5 | villa carlos paz
# Processing Record 26 of Set 5 | port moresby
# Processing Record 27 of Set 5 | belle glade
# Processing Record 28 of Set 5 | kungurtug
# Processing Record 29 of Set 5 | kolvereid
# Processing Record 30 of Set 5 | robertsport
# Processing Record 31 of Set 5 | yellowknife
# Processing Record 32 of Set 5 | adre
# Processing Record 33 of Set 5 | boyle
# Processing Record 34 of Set 5 | pryazha
# Processing Record 35 of Set 5 | linchuan
# City not found. Skipping...
# Processing Record 36 of Set 5 | tuktoyaktuk
# Processing Record 37 of Set 5 | hami
# Processing Record 38 of Set 5 | bababe
# City not found. Skipping...
# Processing Record 39 of Set 5 | miraflores
# Processing Record 40 of Set 5 | banda aceh
# Processing Record 41 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 5 | ambulu
# Processing Record 43 of Set 5 | gisborne
# Processing Record 44 of Set 5 | prince rupert
# Processing Record 45 of Set 5 | aksay
# Processing Record 46 of Set 5 | bethlehem
# Processing Record 47 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 5 | bosaso
# Processing Record 49 of Set 5 | flinders
# Processing Record 50 of Set 5 | broome
# Processing Record 1 of Set 6 | utete
# Processing Record 2 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 3 of Set 6 | lazaro cardenas
# Processing Record 4 of Set 6 | stekolnyy
# City not found. Skipping...
# Processing Record 5 of Set 6 | ketchikan
# Processing Record 6 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 6 | pacific grove
# Processing Record 8 of Set 6 | hobyo
# Processing Record 9 of Set 6 | zolnoye
# City not found. Skipping...
# Processing Record 10 of Set 6 | samarai
# Processing Record 11 of Set 6 | prata
# Processing Record 12 of Set 6 | grindavik
# Processing Record 13 of Set 6 | babanusah
# City not found. Skipping...
# Processing Record 14 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 15 of Set 6 | huntsville
# Processing Record 16 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 17 of Set 6 | tual
# Processing Record 18 of Set 6 | chuy
# Processing Record 19 of Set 6 | jiaocheng
# Processing Record 20 of Set 6 | rohatyn
# Processing Record 21 of Set 6 | el oro
# Processing Record 22 of Set 6 | cidreira
# Processing Record 23 of Set 6 | santiago
# Processing Record 24 of Set 6 | gravdal
# Processing Record 25 of Set 6 | pacasmayo
# Processing Record 26 of Set 6 | maniwaki
# Processing Record 27 of Set 6 | belyy yar
# Processing Record 28 of Set 6 | green river
# Processing Record 29 of Set 6 | juba
# Processing Record 30 of Set 6 | kapiri mposhi
# Processing Record 31 of Set 6 | port blair
# Processing Record 32 of Set 6 | reo
# Processing Record 33 of Set 6 | arona
# Processing Record 34 of Set 6 | jiwani
# Processing Record 35 of Set 6 | salym
# Processing Record 36 of Set 6 | souillac
# Processing Record 37 of Set 6 | noumea
# Processing Record 38 of Set 6 | sabzevar
# Processing Record 39 of Set 6 | pedernales
# Processing Record 40 of Set 6 | eureka
# Processing Record 41 of Set 6 | arraial do cabo
# Processing Record 42 of Set 6 | lithgow
# Processing Record 43 of Set 6 | kavaratti
# Processing Record 44 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 6 | mount isa
# Processing Record 46 of Set 6 | maldonado
# Processing Record 47 of Set 6 | skibbereen
# Processing Record 48 of Set 6 | graaff-reinet
# Processing Record 49 of Set 6 | comodoro rivadavia
# Processing Record 50 of Set 6 | alofi
# Processing Record 1 of Set 7 | pisco
# Processing Record 2 of Set 7 | paine
# Processing Record 3 of Set 7 | tilichiki
# Processing Record 4 of Set 7 | kinablangan
# Processing Record 5 of Set 7 | hegra
# Processing Record 6 of Set 7 | camacha
# Processing Record 7 of Set 7 | arica
# Processing Record 8 of Set 7 | lebu
# Processing Record 9 of Set 7 | madang
# Processing Record 10 of Set 7 | atar
# Processing Record 11 of Set 7 | pringsewu
# Processing Record 12 of Set 7 | anlu
# Processing Record 13 of Set 7 | oranjemund
# Processing Record 14 of Set 7 | oussouye
# Processing Record 15 of Set 7 | murgab
# Processing Record 16 of Set 7 | kirovsk
# Processing Record 17 of Set 7 | ambon
# Processing Record 18 of Set 7 | rio grande
# Processing Record 19 of Set 7 | lagoa
# Processing Record 20 of Set 7 | sabha
# Processing Record 21 of Set 7 | ilulissat
# Processing Record 22 of Set 7 | tabuk
# Processing Record 23 of Set 7 | atka
# City not found. Skipping...
# Processing Record 24 of Set 7 | celestun
# Processing Record 25 of Set 7 | balikpapan
# Processing Record 26 of Set 7 | meulaboh
# Processing Record 27 of Set 7 | nangomba
# Processing Record 28 of Set 7 | bure
# Processing Record 29 of Set 7 | itarema
# Processing Record 30 of Set 7 | vao
# Processing Record 31 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 7 | george town
# Processing Record 33 of Set 7 | eldikan
# City not found. Skipping...
# Processing Record 34 of Set 7 | belmonte
# Processing Record 35 of Set 7 | santa maria
# Processing Record 36 of Set 7 | adzhamka
# Processing Record 37 of Set 7 | hailey
# Processing Record 38 of Set 7 | birjand
# Processing Record 39 of Set 7 | emerald
# Processing Record 40 of Set 7 | panzhihua
# Processing Record 41 of Set 7 | maniitsoq
# Processing Record 42 of Set 7 | grande prairie
# Processing Record 43 of Set 7 | vilyuysk
# Processing Record 44 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 45 of Set 7 | olinda
# Processing Record 46 of Set 7 | leningradskiy
# Processing Record 47 of Set 7 | brigantine
# Processing Record 48 of Set 7 | xghajra
# City not found. Skipping...
# Processing Record 49 of Set 7 | mantua
# Processing Record 50 of Set 7 | flin flon
# Processing Record 1 of Set 8 | andevoranto
# City not found. Skipping...
# Processing Record 2 of Set 8 | misratah
# Processing Record 3 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 8 | kingman
# Processing Record 5 of Set 8 | pierre
# Processing Record 6 of Set 8 | bethel
# Processing Record 7 of Set 8 | quatre cocos
# Processing Record 8 of Set 8 | alamosa
# Processing Record 9 of Set 8 | vanderhoof
# Processing Record 10 of Set 8 | ngunguru
# Processing Record 11 of Set 8 | qafsah
# City not found. Skipping...
# Processing Record 12 of Set 8 | mahebourg
# Processing Record 13 of Set 8 | abu samrah
# Processing Record 14 of Set 8 | garowe
# Processing Record 15 of Set 8 | adrar
# Processing Record 16 of Set 8 | pemangkat
# Processing Record 17 of Set 8 | axim
# Processing Record 18 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 19 of Set 8 | ostrovnoy
# Processing Record 20 of Set 8 | kavieng
# Processing Record 21 of Set 8 | villanueva de la serena
# Processing Record 22 of Set 8 | port hardy
# Processing Record 23 of Set 8 | aljezur
# Processing Record 24 of Set 8 | lincoln
# Processing Record 25 of Set 8 | umm lajj
# Processing Record 26 of Set 8 | columbus
# Processing Record 27 of Set 8 | san carlos
# Processing Record 28 of Set 8 | peleduy
# Processing Record 29 of Set 8 | geresk
# City not found. Skipping...
# Processing Record 30 of Set 8 | chapleau
# Processing Record 31 of Set 8 | cockburn town
# Processing Record 32 of Set 8 | novo aripuana
# Processing Record 33 of Set 8 | ankang
# Processing Record 34 of Set 8 | tigil
# Processing Record 35 of Set 8 | zabol
# Processing Record 36 of Set 8 | sabang
# Processing Record 37 of Set 8 | paragominas
# Processing Record 38 of Set 8 | mayo
# Processing Record 39 of Set 8 | fort nelson
# Processing Record 40 of Set 8 | calera
# Processing Record 41 of Set 8 | solnechnyy
# Processing Record 42 of Set 8 | lalmohan
# Processing Record 43 of Set 8 | aksu
# Processing Record 44 of Set 8 | san jeronimo
# Processing Record 45 of Set 8 | saint anthony
# Processing Record 46 of Set 8 | abrau-dyurso
# Processing Record 47 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 48 of Set 8 | san quintin
# Processing Record 49 of Set 8 | rocha
# Processing Record 50 of Set 8 | pangnirtung
# Processing Record 1 of Set 9 | aykhal
# Processing Record 2 of Set 9 | ayagoz
# Processing Record 3 of Set 9 | junqueiropolis
# Processing Record 4 of Set 9 | faanui
# Processing Record 5 of Set 9 | gusau
# Processing Record 6 of Set 9 | barra
# Processing Record 7 of Set 9 | bethanien
# Processing Record 8 of Set 9 | nioro
# Processing Record 9 of Set 9 | koboldo
# City not found. Skipping...
# Processing Record 10 of Set 9 | presidencia roque saenz pena
# Processing Record 11 of Set 9 | saint-denis
# Processing Record 12 of Set 9 | fortuna
# Processing Record 13 of Set 9 | luziania
# Processing Record 14 of Set 9 | kodinsk
# Processing Record 15 of Set 9 | alice springs
# Processing Record 16 of Set 9 | chumikan
# Processing Record 17 of Set 9 | egvekinot
# Processing Record 18 of Set 9 | melfi
# Processing Record 19 of Set 9 | harper
# Processing Record 20 of Set 9 | ballarat
# Processing Record 21 of Set 9 | arlit
# Processing Record 22 of Set 9 | altay
# Processing Record 23 of Set 9 | eidfjord
# Processing Record 24 of Set 9 | westport
# Processing Record 25 of Set 9 | itoman
# Processing Record 26 of Set 9 | mosquera
# Processing Record 27 of Set 9 | longyearbyen
# Processing Record 28 of Set 9 | nizhniy kuranakh
# Processing Record 29 of Set 9 | miramar
# Processing Record 30 of Set 9 | cam pha
# City not found. Skipping...
# Processing Record 31 of Set 9 | kamenka
# Processing Record 32 of Set 9 | maltahohe
# Processing Record 33 of Set 9 | guerrero negro
# Processing Record 34 of Set 9 | beira
# Processing Record 35 of Set 9 | erenhot
# Processing Record 36 of Set 9 | carballo
# Processing Record 37 of Set 9 | davila
# Processing Record 38 of Set 9 | jieshi
# Processing Record 39 of Set 9 | iwanai
# Processing Record 40 of Set 9 | syedove
# Processing Record 41 of Set 9 | paytug
# City not found. Skipping...
# Processing Record 42 of Set 9 | kendari
# Processing Record 43 of Set 9 | dudinka
# Processing Record 44 of Set 9 | sibu
# Processing Record 45 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 46 of Set 9 | puerto ayacucho
# Processing Record 47 of Set 9 | bandarbeyla
# Processing Record 48 of Set 9 | inzer
# Processing Record 49 of Set 9 | kiunga
# Processing Record 50 of Set 9 | tarko-sale
# Processing Record 1 of Set 10 | sayansk
# Processing Record 2 of Set 10 | mahon
# Processing Record 3 of Set 10 | isla mujeres
# Processing Record 4 of Set 10 | northam
# Processing Record 5 of Set 10 | wanxian
# Processing Record 6 of Set 10 | majene
# Processing Record 7 of Set 10 | eyl
# Processing Record 8 of Set 10 | kholodnyy
# Processing Record 9 of Set 10 | coihaique
# Processing Record 10 of Set 10 | carutapera
# Processing Record 11 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 12 of Set 10 | angoche
# Processing Record 13 of Set 10 | tevaitoa
# Processing Record 14 of Set 10 | manavalakurichi
# Processing Record 15 of Set 10 | coquimbo
# Processing Record 16 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 17 of Set 10 | lishu
# Processing Record 18 of Set 10 | hualmay
# Processing Record 19 of Set 10 | fallon
# Processing Record 20 of Set 10 | caceres
# Processing Record 21 of Set 10 | kabinda
# Processing Record 22 of Set 10 | dunedin
# Processing Record 23 of Set 10 | bambous virieux
# Processing Record 24 of Set 10 | civitanova marche
# Processing Record 25 of Set 10 | lorengau
# Processing Record 26 of Set 10 | zavallya
# Processing Record 27 of Set 10 | hondo
# Processing Record 28 of Set 10 | san matias
# Processing Record 29 of Set 10 | henties bay
# Processing Record 30 of Set 10 | yar-sale
# Processing Record 31 of Set 10 | mapiripan
# Processing Record 32 of Set 10 | mbanza-ngungu
# Processing Record 33 of Set 10 | herat
# Processing Record 34 of Set 10 | kempsey
# Processing Record 35 of Set 10 | porto walter
# Processing Record 36 of Set 10 | dongsheng
# Processing Record 37 of Set 10 | baraya
# Processing Record 38 of Set 10 | los llanos de aridane
# Processing Record 39 of Set 10 | whitianga
# Processing Record 40 of Set 10 | kampene
# Processing Record 41 of Set 10 | verkhoyansk
# Processing Record 42 of Set 10 | akureyri
# Processing Record 43 of Set 10 | marsh harbour
# Processing Record 44 of Set 10 | matara
# Processing Record 45 of Set 10 | banjar
# Processing Record 46 of Set 10 | lashio
# Processing Record 47 of Set 10 | rolla
# Processing Record 48 of Set 10 | cururupu
# Processing Record 49 of Set 10 | puquio
# Processing Record 50 of Set 10 | karaton
# Processing Record 1 of Set 11 | aktash
# Processing Record 2 of Set 11 | hoquiam
# Processing Record 3 of Set 11 | kernersville
# Processing Record 4 of Set 11 | surat
# Processing Record 5 of Set 11 | vostok
# Processing Record 6 of Set 11 | fraga
# Processing Record 7 of Set 11 | kulhudhuffushi
# Processing Record 8 of Set 11 | trinidad
# Processing Record 9 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 10 of Set 11 | alpena
# Processing Record 11 of Set 11 | wanning
# Processing Record 12 of Set 11 | gorontalo
# Processing Record 13 of Set 11 | sambava
# Processing Record 14 of Set 11 | punta alta
# Processing Record 15 of Set 11 | izhma
# Processing Record 16 of Set 11 | lumphat
# Processing Record 17 of Set 11 | vila do maio
# Processing Record 18 of Set 11 | sao jose da coroa grande
# Processing Record 19 of Set 11 | sinnamary
# Processing Record 20 of Set 11 | bilibino
# Processing Record 21 of Set 11 | mecca
# Processing Record 22 of Set 11 | yumen
# Processing Record 23 of Set 11 | lianzhou
# Processing Record 24 of Set 11 | salas
# Processing Record 25 of Set 11 | kangaatsiaq
# Processing Record 26 of Set 11 | paidha
# Processing Record 27 of Set 11 | russkaya polyana
# Processing Record 28 of Set 11 | at-bashi
# Processing Record 29 of Set 11 | pandan
# Processing Record 30 of Set 11 | changli
# Processing Record 31 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 32 of Set 11 | kununurra
# Processing Record 33 of Set 11 | liepaja
# Processing Record 34 of Set 11 | kaitangata
# Processing Record 35 of Set 11 | marshalltown
# Processing Record 36 of Set 11 | burnie
# Processing Record 37 of Set 11 | college
# Processing Record 38 of Set 11 | berdigestyakh
# Processing Record 39 of Set 11 | risor
# Processing Record 40 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 41 of Set 11 | santa vitoria do palmar
# Processing Record 42 of Set 11 | coahuayana
# Processing Record 43 of Set 11 | bethany
# Processing Record 44 of Set 11 | sobolevo
# Processing Record 45 of Set 11 | smithers
# Processing Record 46 of Set 11 | alekseyevsk
# Processing Record 47 of Set 11 | skalat
# Processing Record 48 of Set 11 | qaqortoq
# Processing Record 49 of Set 11 | wankaner
# Processing Record 50 of Set 11 | gulu
# Processing Record 1 of Set 12 | bay roberts
# Processing Record 2 of Set 12 | dhilwan
# Processing Record 3 of Set 12 | gewane
# Processing Record 4 of Set 12 | kasempa
# Processing Record 5 of Set 12 | canton
# Processing Record 6 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 12 | rawson
# Processing Record 8 of Set 12 | igrim
# Processing Record 9 of Set 12 | kathmandu
# Processing Record 10 of Set 12 | ilula
# Processing Record 11 of Set 12 | ishigaki
# Processing Record 12 of Set 12 | santa fe
# Processing Record 13 of Set 12 | pathein
# Processing Record 14 of Set 12 | rundu
# Processing Record 15 of Set 12 | zhangjiakou
# Processing Record 16 of Set 12 | iranshahr
# Processing Record 17 of Set 12 | zaykovo
# Processing Record 18 of Set 12 | vardo
# Processing Record 19 of Set 12 | kudat
# Processing Record 20 of Set 12 | mazatlan
# Processing Record 21 of Set 12 | payo
# Processing Record 22 of Set 12 | ondangwa
# Processing Record 23 of Set 12 | shingu
# Processing Record 24 of Set 12 | igarape-acu
# City not found. Skipping...
# Processing Record 25 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 26 of Set 12 | gazli
# Processing Record 27 of Set 12 | berlevag
# Processing Record 28 of Set 12 | opuwo
# Processing Record 29 of Set 12 | praia
# Processing Record 30 of Set 12 | mamallapuram
# Processing Record 31 of Set 12 | shepsi
# Processing Record 32 of Set 12 | hunterville
# Processing Record 33 of Set 12 | kargil
# Processing Record 34 of Set 12 | saint-gaudens
# Processing Record 35 of Set 12 | sfantu gheorghe
# Processing Record 36 of Set 12 | funadhoo
# Processing Record 37 of Set 12 | gunjur
# Processing Record 38 of Set 12 | sanming
# Processing Record 39 of Set 12 | sola
# Processing Record 40 of Set 12 | faya
# Processing Record 41 of Set 12 | nueve de julio
# Processing Record 42 of Set 12 | leh
# Processing Record 43 of Set 12 | fianga
# City not found. Skipping...
# Processing Record 44 of Set 12 | honningsvag
# Processing Record 45 of Set 12 | kosh-agach
# Processing Record 46 of Set 12 | tura
# Processing Record 47 of Set 12 | maiduguri
# Processing Record 48 of Set 12 | chute-aux-outardes
# Processing Record 49 of Set 12 | burns lake
# Processing Record 50 of Set 12 | hudson bay
# Processing Record 1 of Set 13 | namatanai
# Processing Record 2 of Set 13 | airai
# Processing Record 3 of Set 13 | nemours
# Processing Record 4 of Set 13 | abu kamal
# Processing Record 5 of Set 13 | khaniotis
# Processing Record 6 of Set 13 | sohag
# Processing Record 7 of Set 13 | okato
# Processing Record 8 of Set 13 | puerto carreno
# Processing Record 9 of Set 13 | hambantota
# Processing Record 10 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 13 | zhigansk
# Processing Record 12 of Set 13 | north battleford
# Processing Record 13 of Set 13 | eskasem
# City not found. Skipping...
# Processing Record 14 of Set 13 | koslan
# Processing Record 15 of Set 13 | sarankhola
# Processing Record 16 of Set 13 | bontang
# Processing Record 17 of Set 13 | ayan
# Processing Record 18 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 19 of Set 13 | homer
# Processing Record 20 of Set 13 | assiniboia
# Processing Record 21 of Set 13 | klaksvik
# Processing Record 22 of Set 13 | masunga
# Processing Record 23 of Set 13 | nome
# Processing Record 24 of Set 13 | amapa
# Processing Record 25 of Set 13 | lensk
# Processing Record 26 of Set 13 | shache
# Processing Record 27 of Set 13 | bud
# Processing Record 28 of Set 13 | forest
# Processing Record 29 of Set 13 | kananga
# Processing Record 30 of Set 13 | progreso
# Processing Record 31 of Set 13 | senneterre
# Processing Record 32 of Set 13 | tuatapere
# Processing Record 33 of Set 13 | chippewa falls
# Processing Record 34 of Set 13 | impfondo
# Processing Record 35 of Set 13 | karatau
# Processing Record 36 of Set 13 | massaguet
# Processing Record 37 of Set 13 | lompoc
# Processing Record 38 of Set 13 | estacion coahuila
# Processing Record 39 of Set 13 | luganville
# Processing Record 40 of Set 13 | luanda
# Processing Record 41 of Set 13 | khandbari
# Processing Record 42 of Set 13 | silvia
# Processing Record 43 of Set 13 | iskateley
# Processing Record 44 of Set 13 | esperantina
# Processing Record 45 of Set 13 | shenjiamen
# Processing Record 46 of Set 13 | tautira
# Processing Record 47 of Set 13 | tawang
# Processing Record 48 of Set 13 | senaki
# Processing Record 49 of Set 13 | ibra
# Processing Record 50 of Set 13 | jaciara
# Processing Record 1 of Set 14 | dhidhdhoo
# Processing Record 2 of Set 14 | linxia
# Processing Record 3 of Set 14 | dickson
# Processing Record 4 of Set 14 | krasnoselkup
# Processing Record 5 of Set 14 | chepareria
# Processing Record 6 of Set 14 | igboho
# Processing Record 7 of Set 14 | barcelos
# Processing Record 8 of Set 14 | wanaka
# Processing Record 9 of Set 14 | imbituba
# Processing Record 10 of Set 14 | bonthe
# Processing Record 11 of Set 14 | kuandian
# Processing Record 12 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 13 of Set 14 | la union
# Processing Record 14 of Set 14 | manggar
# Processing Record 15 of Set 14 | bengkulu
# Processing Record 16 of Set 14 | chabahar
# Processing Record 17 of Set 14 | chanderi
# Processing Record 18 of Set 14 | kamaishi
# Processing Record 19 of Set 14 | santa cruz
# Processing Record 20 of Set 14 | rupert
# Processing Record 21 of Set 14 | rosarito
# Processing Record 22 of Set 14 | ende
# Processing Record 23 of Set 14 | kalabo
# Processing Record 24 of Set 14 | xining
# Processing Record 25 of Set 14 | morondava
# Processing Record 26 of Set 14 | tazovskiy
# Processing Record 27 of Set 14 | saint-georges
# Processing Record 28 of Set 14 | bacolod
# Processing Record 29 of Set 14 | vrangel
# Processing Record 30 of Set 14 | walvis bay
# Processing Record 31 of Set 14 | beyneu
# Processing Record 32 of Set 14 | sumbe
# Processing Record 33 of Set 14 | bayanday
# Processing Record 34 of Set 14 | tromso
# Processing Record 35 of Set 14 | disna
# Processing Record 36 of Set 14 | heihe
# Processing Record 37 of Set 14 | shimoda
# Processing Record 38 of Set 14 | riverton
# Processing Record 39 of Set 14 | beno-yurt
# City not found. Skipping...
# Processing Record 40 of Set 14 | longuenesse
# Processing Record 41 of Set 14 | safaga
# Processing Record 42 of Set 14 | kirov
# Processing Record 43 of Set 14 | yaan
# Processing Record 44 of Set 14 | bremerton
# Processing Record 45 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 46 of Set 14 | keffi
# Processing Record 47 of Set 14 | roblin
# Processing Record 48 of Set 14 | dargaville
# Processing Record 49 of Set 14 | griffith
# Processing Record 50 of Set 14 | sumenep
# Processing Record 1 of Set 15 | linda
# Processing Record 2 of Set 15 | salinopolis
# Processing Record 3 of Set 15 | pokhara
# Processing Record 4 of Set 15 | myitkyina
# Processing Record 5 of Set 15 | kloulklubed
# Processing Record 6 of Set 15 | biggar
# Processing Record 7 of Set 15 | benguela
# Processing Record 8 of Set 15 | lakes entrance
# Processing Record 9 of Set 15 | ust-shonosha
# Processing Record 10 of Set 15 | galle
# Processing Record 11 of Set 15 | gazanjyk
# Processing Record 12 of Set 15 | puerto guzman
# Processing Record 13 of Set 15 | tignere
# Processing Record 14 of Set 15 | bela
# Processing Record 15 of Set 15 | talcahuano
# Processing Record 16 of Set 15 | dutlwe
# Processing Record 17 of Set 15 | kaa-khem
# Processing Record 18 of Set 15 | palmer
# Processing Record 19 of Set 15 | yerbogachen
# Processing Record 20 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 21 of Set 15 | ucluelet
# Processing Record 22 of Set 15 | abapo
# Processing Record 23 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 15 | surt
# Processing Record 25 of Set 15 | magdalena
# Processing Record 26 of Set 15 | malanje
# Processing Record 27 of Set 15 | cayenne
# Processing Record 28 of Set 15 | jahrom
# City not found. Skipping...
# Processing Record 29 of Set 15 | shu
# Processing Record 30 of Set 15 | arbazh
# Processing Record 31 of Set 15 | jatni
# City not found. Skipping...
# Processing Record 32 of Set 15 | ipilan
# Processing Record 33 of Set 15 | manado
# Processing Record 34 of Set 15 | peniche
# Processing Record 35 of Set 15 | sorland
# Processing Record 36 of Set 15 | alibag
# Processing Record 37 of Set 15 | nichinan
# Processing Record 38 of Set 15 | kokopo
# Processing Record 39 of Set 15 | narasapur
# Processing Record 40 of Set 15 | yerofey pavlovich
# -----------------------------
# Data Retrieval Complete

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Arvika  59.6553   12.5852     32.70        99         100        7.18
# 1    Khatanga  71.9667  102.5000    -34.53       100         100        4.99
# 2       Bluff -46.6000  168.3333     55.80        79         100        9.66
# 3  Nanortalik  60.1432  -45.2371     27.73        79         100        5.37
# 4     Yajalon  17.2333  -92.3333     75.02        40          13        3.42
# 5       Lodja  -3.4833   23.4333     74.01        85          96        2.44
# 6        Poum -20.2333  164.0167     81.77        78         100       13.58
# 7     Ahipara -35.1667  173.1667     63.99        96          77        5.03
# 8     Mataura -46.1927  168.8643     55.47        95         100        1.41
# 9      Beloha -25.1667   45.0500     75.92        79          95       10.29
#
#   Country                 Date      Description
# 0      SE  2021-12-10 17:39:51       light snow
# 1      RU  2021-12-10 17:35:23  overcast clouds
# 2      NZ  2021-12-10 17:32:29  overcast clouds
# 3      GL  2021-12-10 17:39:52  overcast clouds
# 4      MX  2021-12-10 17:39:53       few clouds
# 5      CD  2021-12-10 17:39:53       light rain
# 6      NC  2021-12-10 17:34:04  overcast clouds
# 7      NZ  2021-12-10 17:39:54    broken clouds
# 8      NZ  2021-12-10 17:32:36  overcast clouds
# 9      MG  2021-12-10 17:39:55  overcast clouds

# %%
column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]

# %%
city_data_df = city_data_df[column_order]
city_data_df
# Out:
#                   City Country                 Date      Lat       Lng  \
# 0               Arvika      SE  2021-12-10 17:39:51  59.6553   12.5852
# 1             Khatanga      RU  2021-12-10 17:35:23  71.9667  102.5000
# 2                Bluff      NZ  2021-12-10 17:32:29 -46.6000  168.3333
# 3           Nanortalik      GL  2021-12-10 17:39:52  60.1432  -45.2371
# 4              Yajalon      MX  2021-12-10 17:39:53  17.2333  -92.3333
# ..                 ...     ...                  ...      ...       ...
# 674             Alibag      IN  2021-12-10 17:59:38  18.6411   72.8792
# 675           Nichinan      JP  2021-12-10 17:59:38  31.6000  131.3667
# 676             Kokopo      PG  2021-12-10 17:59:39  -4.3520  152.2633
# 677          Narasapur      IN  2021-12-10 17:59:39  16.4500   81.6667
# 678  Yerofey Pavlovich      RU  2021-12-10 17:59:40  53.9667  121.9667
#
#      Max Temp  Humidity  Cloudiness  Wind Speed      Description
# 0       32.70        99         100        7.18       light snow
# 1      -34.53       100         100        4.99  overcast clouds
# 2       55.80        79         100        9.66  overcast clouds
# 3       27.73        79         100        5.37  overcast clouds
# 4       75.02        40          13        3.42       few clouds
# ..        ...       ...         ...         ...              ...
# 674     82.47        66           0        6.29        clear sky
# 675     52.75        83           2        3.33        clear sky
# 676     77.27        85         100        2.48  overcast clouds
# 677     73.85        89           1        6.64       light rain
# 678      4.06        98         100        1.10  overcast clouds
#
# [679 rows x 10 columns]

# %%
# Create the output file (CSV).
output_df = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_df, index_label="City_ID")
